# %%
from data_loader import load_smnist
from data_loader import plot_mnist
import numpy as np

# %%
x_train, y_train, x_test, y_test = load_smnist(n=1, one_hot_enc=False, flatten=True, normalized=True)

print('max:', np.max(x_train), np.max(x_test))
print('min:', np.min(x_train), np.min(x_test))
print('shape:',x_train.shape, y_train.shape)
print('shape:',x_test.shape, y_test.shape)
plot_mnist(x_train, 10, 1)
# Out:
# auto download is active, attempting download
# mnist data directory already exists, download aborted
# auto download is active, attempting download
# mnist data directory already exists, download aborted
# max: 0.99609375 0.99609375
# min: 0.0 0.0
# shape: (10, 784) (10,)
# shape: (10000, 784) (10000,)

# %%
x_train, y_train, x_test, y_test = load_smnist(n=5, one_hot_enc=True, flatten=False, normalized=False)

print('max:', np.max(x_train), np.max(x_test))
print('min:', np.min(x_train), np.min(x_test))
print('shape:',x_train.shape, y_train.shape)
print('shape:',x_test.shape, y_test.shape)
plot_mnist(x_train, 10, 5)
# Out:
# auto download is active, attempting download
# mnist data directory already exists, download aborted
# auto download is active, attempting download
# mnist data directory already exists, download aborted
# max: 255 255
# min: 0 0
# shape: (50, 28, 28) (50, 10)
# shape: (10000, 28, 28) (10000, 10)
